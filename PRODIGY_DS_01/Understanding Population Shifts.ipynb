# %% [markdown]
# # **Understanding Population Shifts**

# %% [markdown]
# ## **Problem Statement :**
# **Create a bar chart or histogram to visualize the distribution of categorical or continous variable, such as the distribution of ages or gender in a population**

# %% [markdown]
# ###**Author/Coder :**  [**Sumit Baviskar**](https://www.linkedin.com/in/sumit-baviskar/)

# %% [markdown]
# ###**Dataset Link  :** [**World Bank Group**](https://data.worldbank.org/indicator/SP.POP.TOTL)

# %% [markdown]
# ## **Introduction :**
#
# The purpose of this project is to analyze the distribution of population demographics using the dataset provided by the World Bank. Understanding demographic distributions is critical for decision-making in various sectors, including public policy, health care, and urban planning. By visualizing the data, we aim to uncover patterns and trends that can guide resource allocation and program development effectively.
#
# The specific goal of this project is to create a visual representation (bar chart or histogram) of a key variable, such as the age or gender distribution, within a population. Such visualizations provide an intuitive understanding of the dataset, making it easier to identify anomalies, trends, or gaps.

# %% [markdown]
# ### **Purpose of the Project :**
#
# The primary purpose of this project is to analyze and visualize population data to gain insights into demographic distributions across different countries or regions. By exploring trends and patterns in the data, this project aims to address the following objectives:
#
# 1. **Understand Population Distribution**:
#    - Identify how populations are distributed globally, regionally, or within specific countries.
#    - Highlight variations in population size, growth, or decline over time.
#
# 2. **Support Decision-Making**:
#    - Provide actionable insights for policymakers, researchers, and stakeholders to make informed decisions about resource allocation, urban planning, and public services.
#
# 3. **Highlight Demographic Trends**:
#    - Explore patterns such as urbanization, aging populations, or gender imbalances.
#    - Examine how these trends vary across regions or economic conditions.
#
# 4. **Improve Data Accessibility and Communication**:
#    - Transform raw population data into intuitive visualizations that make complex information accessible to a broader audience.
#    - Facilitate better understanding through clear and engaging graphical representation.
#
# This project emphasizes the role of data visualization in uncovering hidden trends and presenting them in a way that informs and inspires actionable solutions for societal challenges.

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Data
pop_data=pd.read_csv("/content/World Bank Population.csv")

# %%
# Importing Data
country_data=pd.read_csv("/content/Country Metadata.csv")

# %%
pop_data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
pop_data.describe() # descriptive summary
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172712e+08  1.188807e+08  1.210511e+08  1.237333e+08  1.264378e+08
# std    3.695439e+08  3.740897e+08  3.808061e+08  3.895039e+08  3.982439e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291813e+08  1.320404e+08  1.348980e+08  1.378358e+08  1.408789e+08
# ...

# %%
pop_data.info() # informative summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
pop_data = pop_data.loc[:, 'Country Name':'2022']  # Data Filtering

# %%
pop_data.head() # Cheacking Data
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
pop_data.info() # informative summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
pop_data.describe() # descriptive summary
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172712e+08  1.188807e+08  1.210511e+08  1.237333e+08  1.264378e+08
# std    3.695439e+08  3.740897e+08  3.808061e+08  3.895039e+08  3.982439e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291813e+08  1.320404e+08  1.348980e+08  1.378358e+08  1.408789e+08
# ...

# %%
# Checking Unique Values
pop_data.nunique()
# Out:
# Country Name      266
# Country Code      266
# Indicator Name      1
# Indicator Code      1
# 1960              260
#                  ...
# 2018              263
# 2019              263
# 2020              263
# 2021              263
# 2022              263
# Length: 67, dtype: int64

# %%
# Cheacking Null Values
pop_data.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2018              1
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# Length: 67, dtype: int64

# %%
# Filling null values to zero
pop_data.fillna(0, inplace=True)

# %%
# Summing null values
pop_data.isnull().sum().sum()
# Out:
# 0

# %%
# Summing duplicates values and checking duplicates values
pop_data.duplicated().sum()
# Out:
# 0

# %%
country_data.head() # Checking data
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
# summing null values
country_data.isnull().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    139
# TableName         0
# Unnamed: 5      265
# dtype: int64

# %%
country_data.head()  # Cheacking values
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
country_data.info() # informative summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   216 non-null    object
#  3   SpecialNotes  126 non-null    object
#  4   TableName     265 non-null    object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 12.5+ KB

# %%
country_data.describe() # descriptive summary
# Out:
#        Unnamed: 5
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# Filtering data
country_data = country_data.drop(columns=['SpecialNotes', 'Unnamed: 5']).dropna()

# %%
country_data.head(10)  # Cheacking data
# Out:
#    Country Code                      Region          IncomeGroup  \
# 0           ABW   Latin America & Caribbean          High income
# 2           AFG                  South Asia           Low income
# 4           AGO          Sub-Saharan Africa  Lower middle income
# 5           ALB       Europe & Central Asia  Upper middle income
# 6           AND       Europe & Central Asia          High income
# 8           ARE  Middle East & North Africa          High income
# 9           ARG   Latin America & Caribbean  Upper middle income
# 10          ARM       Europe & Central Asia  Upper middle income
# 11          ASM         East Asia & Pacific          High income
# 12          ATG   Latin America & Caribbean          High income
#
#                TableName
# 0                  Aruba
# 2            Afghanistan
# 4                 Angola
# 5                Albania
# 6                Andorra
# 8   United Arab Emirates
# 9              Argentina
# 10               Armenia
# ...

# %%
# Cheacking unique values
country_data.nunique()
# Out:
# Country Code    216
# Region            7
# IncomeGroup       4
# TableName       216
# dtype: int64

# %%
# Summing Duplicates values
country_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## **Data Featuring and Preparing :**

# %%
# Merging Data
df = pop_data.merge(country_data, on='Country Code')
df.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54608.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8622466.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5357195.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL     9443.0
#
#         1961       1962       1963       1964       1965  ...        2016  \
# 0    55811.0    56682.0    57475.0    58178.0    58782.0  ...    104874.0
# 1  8790140.0  8969047.0  9157465.0  9355514.0  9565147.0  ...  34636207.0
# 2  5441333.0  5521400.0  5599827.0  5673199.0  5736582.0  ...  29154746.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2876101.0
# 4    10216.0    11014.0    11839.0    12690.0    13563.0  ...     72540.0
#
#          2017        2018        2019        2020        2021        2022  \
# ...

# %%
# Checking Unique Values
df['IncomeGroup'].unique()
# Out:
# array(['High income', 'Low income', 'Lower middle income',
#        'Upper middle income'], dtype=object)

# %%
# IncomeGroup column should be treated as an ordered categorical variable
from pandas.api.types import CategoricalDtype


df['IncomeGroup'] = (df['IncomeGroup'].str.replace(' income', '')
                            .str.title()
                            .astype(CategoricalDtype(categories=['High', 'Upper Middle', 'Lower Middle', 'Low',], ordered=True)))

# %%
# Checking Data
df.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54608.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8622466.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5357195.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL     9443.0
#
#         1961       1962       1963       1964       1965  ...        2016  \
# 0    55811.0    56682.0    57475.0    58178.0    58782.0  ...    104874.0
# 1  8790140.0  8969047.0  9157465.0  9355514.0  9565147.0  ...  34636207.0
# 2  5441333.0  5521400.0  5599827.0  5673199.0  5736582.0  ...  29154746.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2876101.0
# 4    10216.0    11014.0    11839.0    12690.0    13563.0  ...     72540.0
#
#          2017        2018        2019        2020        2021        2022  \
# ...

# %%
# Filtering data
df['Total Population'] = df.loc[:, '1960':'2022'].sum(axis=1)

# %%
df.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54608.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8622466.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5357195.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL     9443.0
#
#         1961       1962       1963       1964       1965  ...        2017  \
# 0    55811.0    56682.0    57475.0    58178.0    58782.0  ...    105439.0
# 1  8790140.0  8969047.0  9157465.0  9355514.0  9565147.0  ...  35643418.0
# 2  5441333.0  5521400.0  5599827.0  5673199.0  5736582.0  ...  30208628.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2873457.0
# 4    10216.0    11014.0    11839.0    12690.0    13563.0  ...     73837.0
#
#          2018        2019        2020        2021        2022  \
# ...

# %%
df.info() # Informative summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 71 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country Name      216 non-null    object
#  1   Country Code      216 non-null    object
#  2   Indicator Name    216 non-null    object
#  3   Indicator Code    216 non-null    object
#  4   1960              216 non-null    float64
#  5   1961              216 non-null    float64
#  6   1962              216 non-null    float64
#  7   1963              216 non-null    float64
#  8   1964              216 non-null    float64
#  9   1965              216 non-null    float64
#  10  1966              216 non-null    float64
#  11  1967              216 non-null    float64
#  12  1968              216 non-null    float64
#  13  1969              216 non-null    float64
#  14  1970              216 non-null    float64
#  15  1971              216 non-null    float64
# ...

# %%
# Filter the data as per requirement
df_1960_2022 = df[['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']]
df_1960_2022.head()
# Out:
#   Country Name       1960       1961       1962       1963       1964  \
# 0        Aruba    54608.0    55811.0    56682.0    57475.0    58178.0
# 1  Afghanistan  8622466.0  8790140.0  8969047.0  9157465.0  9355514.0
# 2       Angola  5357195.0  5441333.0  5521400.0  5599827.0  5673199.0
# 3      Albania  1608800.0  1659800.0  1711319.0  1762621.0  1814135.0
# 4      Andorra     9443.0    10216.0    11014.0    11839.0    12690.0
#
#         1965       1966        1967        1968  ...        2013        2014  \
# 0    58782.0    59291.0     59522.0     59471.0  ...    102880.0    103594.0
# 1  9565147.0  9783147.0  10010030.0  10247780.0  ...  31541209.0  32716210.0
# 2  5736582.0  5787044.0   5827503.0   5868203.0  ...  26147002.0  27128337.0
# 3  1864791.0  1914573.0   1965598.0   2022272.0  ...   2895092.0   2889104.0
# 4    13563.0    14546.0     15745.0     17079.0  ...     71367.0     71621.0
#
#          2015        2016        2017        2018        2019        2020  \
# ...

# %% [markdown]
# ## **Data Explorating Analysis :**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Transpose the data for easier plotting
df_transposed = df_1960_2022.set_index('Country Name').transpose()

# Calculate the annual sum of the population
annual_sums = df_transposed.sum(axis=1)

# Create the bar plot
plt.figure(figsize=(14, 8))
# Use the Tab10 color palette for unique colors
colors = sns.color_palette("tab10", len(annual_sums))

# Create the bar plot with a different color for each bar
plt.bar(
    annual_sums.index,
    annual_sums.values,
    color=colors
)

# Add labels and title with improved font styling
plt.xlabel("Year", fontsize=14, fontweight='bold')
plt.ylabel("Total Population", fontsize=14, fontweight='bold')
plt.title("Total World Population by Year (1960-2022)", fontsize=16, fontweight='bold')

# Rotate x-axis labels for better readability
plt.xticks(rotation=90, ha="right", fontsize=12)

# Adjust layout to prevent labels from overlapping
plt.tight_layout()

# Display the plot
plt.show()

# %%
# rise in percentage compared to previous year
year=1960
for i in range(len(annual_sums)-1):
  rise=round(((annual_sums[i+1]-annual_sums[i])/annual_sums[i])*100,2)
  print(f"{year+1} has a rise of {rise} in percentage compared to previous year {year}")
  year=year+1
# Out:
# 1961 has a rise of 1.34 in percentage compared to previous year 1960
# 1962 has a rise of 1.76 in percentage compared to previous year 1961
# 1963 has a rise of 2.12 in percentage compared to previous year 1962
# 1964 has a rise of 2.09 in percentage compared to previous year 1963
# 1965 has a rise of 2.07 in percentage compared to previous year 1964
# 1966 has a rise of 2.1 in percentage compared to previous year 1965
# 1967 has a rise of 2.06 in percentage compared to previous year 1966
# 1968 has a rise of 2.06 in percentage compared to previous year 1967
# 1969 has a rise of 2.09 in percentage compared to previous year 1968
# 1970 has a rise of 2.08 in percentage compared to previous year 1969
# 1971 has a rise of 2.1 in percentage compared to previous year 1970
# 1972 has a rise of 2.01 in percentage compared to previous year 1971
# 1973 has a rise of 1.99 in percentage compared to previous year 1972
# 1974 has a rise of 1.93 in percentage compared to previous year 1973
# ...

# %% [markdown]
# ## **Insights :**
#
# - **Peak Population Growth (1963-1971) :** The world experienced its highest population growth rate between 1963 and 1971, with a consistent rise above 2% annually. This indicates a period of significant demographic expansion.
#
# - **Declining Growth Rate (Post-1990) :** From the 1990s onward, the population growth rate shows a steady decline, with rises falling below 1.5% after 1996 and gradually approaching less than 1% in recent years.
#
# - **Sharp Decline in Growth (2020-2022) :** A notable drop in the growth rate is observed from 2020 (1.03%) to 2022 (0.8%), potentially attributable to global events such as the pandemic's impact on birth rates and other demographic factors.

# %%
# Import required libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Select the top 10 countries by population
df_top10 = df.nlargest(10, 'Total Population')

# Set the figure size
plt.figure(figsize=(14, 8))

# Define a custom color palette with unique colors for each bar
custom_colors = sns.color_palette("tab10", len(df_top10))  # Tab10 has a vibrant set of 10 colors

# Create a barplot with the custom color palette
sns.barplot(
    x='Country Name',
    y='Total Population',
    data=df_top10,
    palette=custom_colors
)

# Customize the tick parameters and orientation
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)

# Add grid lines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Add title and axis labels with updated font sizes and styles
plt.title('Top 10 Countries by Total Population (1960-2022)', fontsize=16, fontweight='bold')
plt.xlabel('Country Name', fontsize=14, fontweight='bold')
plt.ylabel('Total Population', fontsize=14, fontweight='bold')

# Adjust the layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## **Insights :**
#
# **Top Population Giants:**
#
# 1. **China and India:** China and India continue to lead the global population charts with total populations exceeding 1.4 billion in recent years (2022).
#
# **Regional Representation:**
#
# - **East Asia & Pacific:** China, Indonesia, Japan
# - **South Asia:** India, Pakistan, Bangladesh
# - **North America:** United States
# - **Sub-Saharan Africa:** Nigeria
# - **Latin America & Caribbean:** Brazil
# - **Europe & Central Asia:** Russia
#
# **Income Groups:**
#
# - **High-Income Countries:** United States, Japan
# - **Upper-Middle-Income Countries:** China, Indonesia, Brazil, Russia
# - **Lower-Middle-Income Countries:** India, Pakistan, Bangladesh, Nigeria
#
# **Population Trends (1960–2022):**
#
# - All countries have consistently grown in population over the decades.
# - **China:** Population grew rapidly until the 2000s, reaching a plateau post-2020.
# - **India:** Shows continuous growth and surpassed China's population in 2022.
# - **Russia and Japan:** Relatively stagnant growth, with Japan showing a slight decline recently.
#
# **Africa’s Growth Potential:**
#
# - Nigeria, representing Sub-Saharan Africa, shows a significant growth rate, reflecting the region's high demographic momentum.
#
# **Total Population Contribution (Cumulative):**
#
# - China and India alone contribute to over 35% of the global population.

# %%
# Group data by region and sum the population for each region
region_population = df.groupby('Region')['Total Population'].sum().sort_values(ascending=True)

# Set the figure size
plt.figure(figsize=(14, 8))

# Create a horizontal bar chart with the Tab10 color palette
region_population.plot.barh(
    color=sns.color_palette("tab10", len(region_population))  # Tab10 palette applied
)

# Add grid lines for better readability
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Add title and axis labels with improved font sizes and styles
plt.title('Total Population by Region', fontsize=16, fontweight='bold')
plt.xlabel('Total Population', fontsize=14, fontweight='bold')
plt.ylabel('Region', fontsize=14, fontweight='bold')

# Increase the font size of tick labels for better visibility
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Adjust the layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## **Insights :**
#
# - **East Asia & Pacific (11.15B):**
# The most populous region, dominated by countries like China, Indonesia, and Japan. This region accounts for a significant share of the global population.
#
#
# - **South Asia (7.56B):**
# The second most populous region, driven primarily by India, Pakistan, and Bangladesh. High population density and rapid growth make it a key region for future demographic trends.
#
#
# - **Europe & Central Asia (5.19B):**
# With countries like Russia, this region has a more stagnant growth trend compared to other regions. Populations here are relatively older, with a focus on sustainable development.
#
#
# - **Sub-Saharan Africa (3.73B):**
# A region showing rapid demographic growth. Nigeria's contribution is significant, with this region emerging as a demographic powerhouse in the future.
#
#
# - **Latin America & Caribbean (2.68B):**
# Steady growth with key countries like Brazil driving the population numbers. Economic development and urbanization are major trends.
#
#
# - **North America (1.80B):**
# Dominated by the United States, this region has a more stable growth rate with high levels of urbanization and economic development.
#
#
# - **Middle East & North Africa (1.71B):**
# This region has a growing population with diverse demographic trends. Countries here face challenges such as water scarcity and youth unemployment.

# %%
# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a count plot with the Tab10 color palette
sns.countplot(
    data=df,
    x='IncomeGroup',
    ax=ax,
    palette=sns.color_palette("tab10")  # Tab10 palette applied
)

# Add title and axis labels with improved styling
ax.set_title('Count of Income Levels', fontsize=16, fontweight='bold')
ax.set_xlabel('Income Group', fontsize=14, fontweight='bold')
ax.set_ylabel('Count', fontsize=14, fontweight='bold')

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)

# Add grid lines for improved readability
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar plot with the Tab10 color palette
sns.barplot(
    data=df,
    x='IncomeGroup',
    y='Total Population',
    palette=sns.color_palette("tab10")  # Tab10 color palette applied
)

# Add title and axis labels with improved styling
ax.set_title('Total Population by Income Level', fontsize=16, fontweight='bold')
ax.set_xlabel('Income Group', fontsize=14, fontweight='bold')
ax.set_ylabel('Total Population', fontsize=14, fontweight='bold')

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)

# Add grid lines for improved readability
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # **Insights :**
#
# **Highest Population in Lower-Income Categories:**
# Lower-middle-income and upper-middle-income groups have the largest populations, indicating that a majority of the world's population falls in these categories.
#
# **Low Population in High-Income Group:**
# The high-income category has the lowest population share, reflecting a limited number of countries with high income per capita.
#
# **Potential for Development:**
# Significant populations in lower-income groups present opportunities for global development efforts, focusing on improved education, infrastructure, and economic growth.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter the data by income levels
income_levels = ['High', 'Upper Middle', 'Lower Middle', 'Low']
filtered_data = df[df['IncomeGroup'].isin(income_levels)]

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharex=True, sharey=True)
axes = axes.flatten()

# Loop through each income level and create a plot
for i, income in enumerate(income_levels):
    sns.histplot(
        data=filtered_data[filtered_data['IncomeGroup'] == income],
        x='Total Population',  # Column for population
        kde=True,
        log_scale=True,
        ax=axes[i],
        color=sns.color_palette("tab10")[i]  # Using Tab10 palette for different colors
    )
    axes[i].set_title(f'{income} Income Group', fontsize=14, fontweight='bold')
    axes[i].set_xlabel('Total Population (log scale)', fontsize=12, fontweight='bold')
    axes[i].set_ylabel('Frequency', fontsize=12, fontweight='bold')

# Adjust layout and add a main title
fig.suptitle('Distribution of Population by Income Levels', fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust to leave space for the title
plt.show()

# %% [markdown]
# ## **Insights :**
#
# - **High-Income Group :**
# The distribution appears slightly skewed, with a larger concentration of populations in the mid-range of total population.
# There are fewer countries with extremely high population sizes in this group.
#
# - **Upper-Middle Income Group :**
# The distribution is relatively balanced, suggesting a more even spread of population sizes across countries in this income level.
# A few countries dominate the higher end of the population spectrum.
#
# - **Lower-Middle Income Group :**
# The distribution is slightly right-skewed, indicating many countries with mid-to-lower population sizes, while a few have significantly larger populations.
# Countries in this group contribute significantly to global population totals.
#
# - **Low-Income Group :**
# The distribution is heavily concentrated towards smaller population sizes.
# Most low-income countries have relatively low population totals compared to other income groups.

# %%
df['Region'].unique()
# Out:
# array(['Latin America & Caribbean', 'South Asia', 'Sub-Saharan Africa',
#        'Europe & Central Asia', 'Middle East & North Africa',
#        'East Asia & Pacific', 'North America'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter the data by the specified regions
regions = [
    'Latin America & Caribbean', 'South Asia', 'Sub-Saharan Africa',
    'Europe & Central Asia', 'Middle East & North Africa',
    'East Asia & Pacific', 'North America'
]
filtered_data = df[df['Region'].isin(regions)]

# Create subplots
fig, axes = plt.subplots(4, 2, figsize=(16, 15 ), sharex=True, sharey=True)
axes = axes.flatten()

# Loop through each region and create a plot
for i, region in enumerate(regions):
    if i < len(axes):  # Ensure we don't exceed subplot slots
        sns.histplot(
            data=filtered_data[filtered_data['Region'] == region],
            x='Total Population',  # Column for population
            kde=True,
            log_scale=True,
            ax=axes[i],
            color=sns.color_palette("tab10")[i]  # Using Tab10 color palette for consistent colors
        )
        axes[i].set_title(f'{region}', fontsize=14, fontweight='bold')
        axes[i].set_xlabel('Total Population (log scale)', fontsize=12, fontweight='bold')
        axes[i].set_ylabel('Frequency', fontsize=12, fontweight='bold')

# Hide any unused axes (if regions < axes slots)
for j in range(len(regions), len(axes)):
    fig.delaxes(axes[j])

# Adjust layout and add a main title
fig.suptitle('Distribution of Population by Region', fontsize=18, fontweight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust to leave space for the title
plt.show()

# %% [markdown]
# ## **Insights :**
#
# - **Latin America & Caribbean :**
#
#  - The population distribution shows moderate variation, with most countries having populations in a mid-range.
#
#  - There are no extreme population outliers in this region.
#
# - **South Asia :**
#
#  - The distribution is highly concentrated towards countries with larger populations.
#
#  - South Asia hosts some of the world's most populous countries, dominating this category.
#
# - **Sub-Saharan Africa :**
#
#  - The distribution is relatively normal, with a notable spread across different population sizes.
#
#  - This region has a significant number of countries with medium-to-large populations.
#
# - **Europe & Central Asia :**
#
#  - Most countries in this region tend to have smaller to medium population sizes.
#
#  - The distribution suggests less variance compared to other regions.
#
# - **Middle East & North Africa :**
#
#  - Population sizes are concentrated toward smaller countries, with very few outliers.
#
#  - Countries in this region generally have smaller populations compared to regions like South Asia.
#
# - **East Asia & Pacific :**
#
#  - The distribution shows a broader range of population sizes, with a few countries dominating the high population end.
#
#  - This region includes both sparsely and densely populated countries.
#
# - **North America :**
#
#  - The population distribution is heavily right-skewed, with most countries having very small populations.
#
#  - A few outliers (e.g., the United States) dominate the region's total population.

# %% [markdown]
# ### **Conclusion :**
#
# The global population trends reveal a dynamic shift in demographic patterns, driven by varying regional, economic, and social factors. Key takeaways include:
#
# 1. **Transition from Rapid Growth to Stabilization**
#    - The world experienced its peak growth in the mid-20th century, but recent decades have shown a steady decline, with growth rates falling below 1% post-2020. This shift highlights the global move toward demographic stabilization in many regions, influenced by declining fertility rates, urbanization, and socioeconomic changes.
#
# 2. **Regional Contrasts**
#    - Rapidly growing regions like **South Asia** and **Sub-Saharan Africa** present significant opportunities for economic development but also face challenges in infrastructure, resource management, and social equity.
#    - In contrast, regions like **Europe & Central Asia** and **North America** show stagnation or decline, emphasizing the need for technology, immigration, and innovation to sustain economic vitality.
#
# 3. **Economic and Demographic Opportunities**
#    - **Lower- and upper-middle-income groups** dominate global population numbers, reflecting untapped potential for economic development and growth. Investments in education, healthcare, and job creation could unlock significant gains in these regions.
#
# 4. **Future Challenges and Opportunities**
#    - Emerging economies, especially in Africa and Asia, must harness their demographic dividend by focusing on youth-centric policies to build skilled workforces.
#    - Meanwhile, aging populations in high-income regions pose challenges in terms of workforce sustainability and social welfare systems, necessitating innovative approaches to maintain productivity.

# %% [markdown]
# ### **Final Thoughts :**
# The global population landscape is marked by stark contrasts, from rapidly expanding regions to stagnating or shrinking ones. Policymakers, businesses, and global institutions must collaborate to address these disparities, fostering inclusive growth while balancing environmental sustainability and resource management. The interplay between demographics and economic strategies will define the global trajectory in the coming decades.
